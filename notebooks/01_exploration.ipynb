# %% [markdown]
# # Brain Rot Project - Data Exploration

# %% [markdown]
# ## 0. Import Libraries

# %%
import pandas as pd
import numpy as np

# This makes pandas show all columns when we print a table
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## 1. Load the Data

# %%
# Load all 5 csv files into pandas dataframes
path = r"F:\Data Analysis\DEPI\Final Final Project\Depi-Data-Analysis-Project(github project structure)\raw_data"

df_fact = pd.read_csv(f"{path}/Fact_User_Activity.csv")
df_users = pd.read_csv(f"{path}/Dim_Users.csv")
df_habits = pd.read_csv(f"{path}/Dim_Habits.csv")
df_mentalstate = pd.read_csv(f"{path}/Dim_MentalState.csv")
df_date = pd.read_csv(f"{path}/Dim_Date.csv")

print("All files loaded successfully!")
# Out:
# All files loaded successfully!

# %% [markdown]
# ## 2. Fact_User_Activity Table

# %%
print("Shape:", df_fact.shape)
# Out:
# Shape: (5000, 14)

# %%
df_fact.columns.tolist()
# Out:
# ['ActivityID',
#  'UserKey',
#  'DateKey',
#  'StateKey',
#  'HabitKey',
#  'Study_Hours',
#  'Coffee_Consumed_Per_Day',
#  'Smoking_Breaks_Count',
#  'Total_Reels_Watched',
#  'Short_Content_Percentage',
#  'Peak_Hour',
#  'Focus_Sessions_Count',
#  'Brainrot_Exposure_Score',
#  'Wellbeing_Score']

# %%
df_fact.head()
# Out:
#    ActivityID  UserKey   DateKey  StateKey  HabitKey  Study_Hours  Coffee_Consumed_Per_Day  Smoking_Breaks_Count  Total_Reels_Watched  Short_Content_Percentage  Peak_Hour  Focus_Sessions_Count  \
# 0           1       90  20261008         4         2          5.4                        1                     9                  198                      0.75         16                     3
# 1           2       62  20260108         1         2          7.6                        3                     0                    2                      0.41         22                     9
# 2           3       45  20260320         2         2          1.2                        2                     0                  125                      0.77         23                     2
# 3           4       76  20261121         1         3          3.5                        2                    11                   18                      0.41          0                     6
# ...

# %%
df_fact.tail()
# Out:
#       ActivityID  UserKey   DateKey  StateKey  HabitKey  Study_Hours  Coffee_Consumed_Per_Day  Smoking_Breaks_Count  Total_Reels_Watched  Short_Content_Percentage  Peak_Hour  Focus_Sessions_Count  \
# 4995        4996       79  20260417         1         1          2.7                        0                     0                   89                      0.45         23                     4
# 4996        4997       37  20260112         1         2          7.1                        5                     0                   21                      0.48          9                     7
# 4997        4998       48  20260908         1         1          3.7                        0                     0                   62                      0.44         17                     5
# 4998        4999       14  20260630         1         2          6.9                        2                     0                   38                      0.43         15                     8
# ...

# %%
df_fact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ActivityID                5000 non-null   int64
#  1   UserKey                   5000 non-null   int64
#  2   DateKey                   5000 non-null   int64
#  3   StateKey                  5000 non-null   int64
#  4   HabitKey                  5000 non-null   int64
#  5   Study_Hours               5000 non-null   float64
#  6   Coffee_Consumed_Per_Day   5000 non-null   int64
#  7   Smoking_Breaks_Count      5000 non-null   int64
#  8   Total_Reels_Watched       5000 non-null   int64
#  9   Short_Content_Percentage  5000 non-null   float64
#  10  Peak_Hour                 5000 non-null   int64
#  11  Focus_Sessions_Count      5000 non-null   int64
#  12  Brainrot_Exposure_Score   5000 non-null   float64
# ...

# %%
df_fact.describe()
# Out:
#         ActivityID      UserKey       DateKey     StateKey    HabitKey  Study_Hours  Coffee_Consumed_Per_Day  Smoking_Breaks_Count  Total_Reels_Watched  Short_Content_Percentage    Peak_Hour  \
# count  5000.000000  5000.000000  5.000000e+03  5000.000000  5000.00000  5000.000000              5000.000000           5000.000000           5000.00000               5000.000000  5000.000000
# mean   2500.500000    50.949600  2.026067e+07     1.879600     1.87080     3.957800                 1.653800              1.304400             91.00680                  0.567646    15.923200
# std    1443.520003    28.926459  3.437548e+02     1.202411     0.56229     2.215654                 2.003684              3.154256             70.24807                  0.170765     6.724935
# min       1.000000     1.000000  2.026010e+07     1.000000     1.00000     0.000000                 0.000000              0.000000              2.00000                  0.400000     0.000000
# ...

# %%
df_fact.isnull().sum()
# Out:
# ActivityID                  0
# UserKey                     0
# DateKey                     0
# StateKey                    0
# HabitKey                    0
# Study_Hours                 0
# Coffee_Consumed_Per_Day     0
# Smoking_Breaks_Count        0
# Total_Reels_Watched         0
# Short_Content_Percentage    0
# Peak_Hour                   0
# Focus_Sessions_Count        0
# Brainrot_Exposure_Score     0
# Wellbeing_Score             0
# dtype: int64

# %%
print("Duplicated rows:", df_fact.duplicated().sum())
# Out:
# Duplicated rows: 0

# %% [markdown]
# ## 3. Dim_Users Table

# %%
print("Shape:", df_users.shape)
# Out:
# Shape: (99, 8)

# %%
print(df_users.columns.tolist())
# Out:
# ['UserKey', 'Username', 'Age', 'Age_Group', 'Region', 'Device_Type', 'Is_Smoker', 'Base_Focus_Level']

# %%
df_users.head()
# Out:
#    UserKey Username  Age Age_Group Region Device_Type  Is_Smoker  Base_Focus_Level
# 0        1   User_1   18      Teen   Suez  Smartphone          1                81
# 1        2   User_2   11     Child   Suez  Smartphone          0                84
# 2        3   User_3   24     Young  Asyut      Tablet          0                62
# 3        4   User_4   16      Teen   Suez  Smartphone          0                73
# 4        5   User_5   15      Teen  Asyut  Smartphone          1                86

# %%
df_users.tail()
# Out:
#     UserKey Username  Age Age_Group Region Device_Type  Is_Smoker  Base_Focus_Level
# 94       95  User_95   17      Teen  Aswan      Tablet          0                67
# 95       96  User_96   11     Child   Giza  Smartphone          0                84
# 96       97  User_97   16      Teen  Cairo      Tablet          0                88
# 97       98  User_98   15      Teen  Minya  Smartphone          1                79
# 98       99  User_99   22     Young  Cairo  Smartphone          0                67

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UserKey           99 non-null     int64
#  1   Username          99 non-null     object
#  2   Age               99 non-null     int64
#  3   Age_Group         99 non-null     object
#  4   Region            99 non-null     object
#  5   Device_Type       99 non-null     object
#  6   Is_Smoker         99 non-null     int64
#  7   Base_Focus_Level  99 non-null     int64
# dtypes: int64(4), object(4)
# memory usage: 6.3+ KB

# %%
df_users.describe()
# Out:
#          UserKey        Age  Is_Smoker  Base_Focus_Level
# count  99.000000  99.000000  99.000000         99.000000
# mean   50.000000  15.555556   0.202020         77.393939
# std    28.722813   4.636198   0.403551         11.408749
# min     1.000000   8.000000   0.000000         60.000000
# 25%    25.500000  12.000000   0.000000         67.000000
# 50%    50.000000  15.000000   0.000000         76.000000
# 75%    74.500000  19.000000   0.000000         88.000000
# max    99.000000  25.000000   1.000000         95.000000

# %%
df_users.isnull().sum()
# Out:
# UserKey             0
# Username            0
# Age                 0
# Age_Group           0
# Region              0
# Device_Type         0
# Is_Smoker           0
# Base_Focus_Level    0
# dtype: int64

# %%
print("Duplicated rows:", df_users.duplicated().sum())
# Out:
# Duplicated rows: 0

# %% [markdown]
# ## 4. Dim_Habits Table

# %%
print("Shape:", df_habits.shape)
df_habits
# Out:
# Shape: (3, 3)
#    HabitKey Coffee_Level Smoking_Status
# 0         1          NaN     Non-Smoker
# 1         2     Moderate     Occasional
# 2         3       Addict   Heavy-Smoker

# %%
df_habits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HabitKey        3 non-null      int64
#  1   Coffee_Level    2 non-null      object
#  2   Smoking_Status  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df_habits.isnull().sum()
# Out:
# HabitKey          0
# Coffee_Level      1
# Smoking_Status    0
# dtype: int64

# %%
print("Duplicated rows:", df_habits.duplicated().sum())
# Out:
# Duplicated rows: 0

# %% [markdown]
# ## 5. Dim_MentalState Table

# %%
print("Shape:", df_mentalstate.shape)
df_mentalstate
# Out:
# Shape: (4, 4)
#    StateKey Attention_Span_Level Brainrot_Stage Aura_Color_Code
# 0         1                 High        Healthy           Green
# 1         2               Medium         Casual          Yellow
# 2         3               Cooked       Advanced             Red
# 3         4                Fried       Critical             Red

# %%
df_mentalstate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StateKey              4 non-null      int64
#  1   Attention_Span_Level  4 non-null      object
#  2   Brainrot_Stage        4 non-null      object
#  3   Aura_Color_Code       4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes

# %%
df_mentalstate.isnull().sum()
# Out:
# StateKey                0
# Attention_Span_Level    0
# Brainrot_Stage          0
# Aura_Color_Code         0
# dtype: int64

# %%
print("Duplicated rows:", df_mentalstate.duplicated().sum())
# Out:
# Duplicated rows: 0

# %% [markdown]
# ## 6. Dim_Date Table

# %%
print("Shape:", df_date.shape)
df_date.head()
# Out:
# Shape: (365, 5)
#     DateKey  FullDate  Is_Late_Night  Is_Exam_Season  Is_Weekend
# 0  20260101  1/1/2026              0               1           0
# 1  20260102  1/2/2026              0               1           1
# 2  20260103  1/3/2026              0               1           1
# 3  20260104  1/4/2026              1               1           0
# 4  20260105  1/5/2026              0               1           0

# %%
df_date.tail()
# Out:
#       DateKey    FullDate  Is_Late_Night  Is_Exam_Season  Is_Weekend
# 360  20261227  12/27/2026              0               0           0
# 361  20261228  12/28/2026              1               0           0
# 362  20261229  12/29/2026              0               0           0
# 363  20261230  12/30/2026              1               0           0
# 364  20261231  12/31/2026              1               0           0

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DateKey         365 non-null    int64
#  1   FullDate        365 non-null    object
#  2   Is_Late_Night   365 non-null    int64
#  3   Is_Exam_Season  365 non-null    int64
#  4   Is_Weekend      365 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 14.4+ KB

# %%
df_date.isnull().sum()
# Out:
# DateKey           0
# FullDate          0
# Is_Late_Night     0
# Is_Exam_Season    0
# Is_Weekend        0
# dtype: int64

# %%
print("Duplicated rows:", df_date.duplicated().sum())
# Out:
# Duplicated rows: 0

# %% [markdown]
# ## 7. Checking Data Types

# %%
print("Fact_User_Activity dtypes:")
print(df_fact.dtypes)
print()
print("Dim_Users dtypes:")
print(df_users.dtypes)
print()
print("Dim_Habits dtypes:")
print(df_habits.dtypes)
print()
print("Dim_MentalState dtypes:")
print(df_mentalstate.dtypes)
print()
print("Dim_Date dtypes:")
print(df_date.dtypes)
# Out:
# Fact_User_Activity dtypes:
# ActivityID                    int64
# UserKey                       int64
# DateKey                       int64
# StateKey                      int64
# HabitKey                      int64
# Study_Hours                 float64
# Coffee_Consumed_Per_Day       int64
# Smoking_Breaks_Count          int64
# Total_Reels_Watched           int64
# Short_Content_Percentage    float64
# Peak_Hour                     int64
# Focus_Sessions_Count          int64
# Brainrot_Exposure_Score     float64
# Wellbeing_Score             float64
# dtype: object
#
# Dim_Users dtypes:
# UserKey              int64
# Username            object
# Age                  int64
# Age_Group           object
# Region              object
# Device_Type         object
# Is_Smoker            int64
# Base_Focus_Level     int64
# dtype: object
#
# Dim_Habits dtypes:
# HabitKey           int64
# Coffee_Level      object
# Smoking_Status    object
# dtype: object
#
# Dim_MentalState dtypes:
# ...

# %% [markdown]
# ## 8. Unique Values in Important Categorical Columns

# %%
print("Age_Group values:", df_users['Age_Group'].unique())
print()
print("Region values:", df_users['Region'].unique())
print()
print("Device_Type values:", df_users['Device_Type'].unique())
print()
print("Coffee_Level values:", df_habits['Coffee_Level'].unique())
print()
print("Smoking_Status values:", df_habits['Smoking_Status'].unique())
print()
print("Attention_Span_Level values:", df_mentalstate['Attention_Span_Level'].unique())
print()
print("Brainrot_Stage values:", df_mentalstate['Brainrot_Stage'].unique())
print()
print("Aura_Color_Code values:", df_mentalstate['Aura_Color_Code'].unique())
# Out:
# Age_Group values: ['Teen' 'Child' 'Young']
#
# Region values: ['Suez' 'Asyut' 'Alexandria' 'Cairo' 'Tanta' 'Aswan' 'Port Said' 'Giza'
#  'Luxor' 'Mansoura' 'Minya']
#
# Device_Type values: ['Smartphone' 'Tablet' 'PC']
#
# Coffee_Level values: [nan 'Moderate' 'Addict']
#
# Smoking_Status values: ['Non-Smoker' 'Occasional' 'Heavy-Smoker']
#
# Attention_Span_Level values: ['High' 'Medium' 'Cooked' 'Fried']
#
# Brainrot_Stage values: ['Healthy' 'Casual' 'Advanced' 'Critical']
#
# Aura_Color_Code values: ['Green' 'Yellow' 'Red']

# %% [markdown]
# ## 9. Simple Frequency Tables

# %%
print("How many users per Age_Group:")
print(df_users['Age_Group'].value_counts())
print()
print("How many users per Region:")
print(df_users['Region'].value_counts())
print()
print("How many users per Device_Type:")
print(df_users['Device_Type'].value_counts())
print()
print("How many activity records per Brainrot Stage (using StateKey for now):")
print(df_fact['StateKey'].value_counts())
# Out:
# How many users per Age_Group:
# Age_Group
# Teen     46
# Child    27
# Young    26
# Name: count, dtype: int64
#
# How many users per Region:
# Region
# Suez          16
# Luxor         11
# Cairo         10
# Aswan         10
# Asyut          9
# Mansoura       9
# Tanta          9
# Giza           9
# Port Said      6
# Minya          6
# Alexandria     4
# Name: count, dtype: int64
#
# How many users per Device_Type:
# Device_Type
# Smartphone    72
# Tablet        18
# PC             9
# Name: count, dtype: int64
#
# How many activity records per Brainrot Stage (using StateKey for now):
# StateKey
# 1    3044
# 4     907
# 3     628
# 2     421
# Name: count, dtype: int64
